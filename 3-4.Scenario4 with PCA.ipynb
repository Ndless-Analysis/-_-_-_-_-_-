# %% [markdown]
# 해당 과제는 'Brightics Studio'로 시작하는 금융 빅데이터 분석 교재를 참고함

# %% [markdown]
# ## 전처리 후 - Feature Selection

# %%
import pandas as pd 
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#시각화 패키지 라이브러리
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #한글깨짐현상방지
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 3. PCA

# %% [markdown]
# 정규화 + 스케일링 + PCA

# %%
df = pd.read_csv('C:/Users/ksy/Desktop/개인/코로나19 팀프로젝트/시나리오2/data/Scaled_data.csv',encoding='cp949')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
x = df.drop(columns=['연체여부'])

# %%
y = df['연체여부']

# %%
len(x.columns)
# Out:
# 60

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# ## 1. 10개의 주성분

# %%
pca = PCA(n_components=10)
pca_componentes = pca.fit_transform(x)
pca_df = pd.DataFrame(data=pca_componentes)

# %%
pca_df.head()
# Out:
#                0              1              2             3              4  \
# 0 -204850.823344   52770.958594  -51743.899749 -74094.166198   21946.601936
# 1  405653.596412 -815190.314699  -72709.247505 -90350.879615   -9774.509541
# 2 -206097.271223   56087.951243  -46743.977044 -74829.805705   22286.637292
# 3 -206110.538085   56100.026687  -52058.258220 -75115.582660   22935.645054
# 4 -198057.263585   36578.193179  549811.023694 -30953.314155  354887.688056
#
#               5             6             7             8             9
# 0 -23300.911133  23727.231379 -30247.425580 -23103.043451   7408.620779
# 1 -26803.618710 -97785.375880   9020.939880  29321.470698 -28361.755620
# 2 -25915.054241 -15540.751158 -25132.762132 -20575.290768   2169.965607
# 3 -25833.536856 -15445.108563 -24569.241033 -20111.361498   6878.748711
# 4 -42251.653597 -20923.866914 -77387.954214 -45056.070940 -90459.007663

# %%
pca.explained_variance_ratio_
# Out:
# array([0.6571778 , 0.08785828, 0.0678797 , 0.06207163, 0.03383588,
#        0.01944202, 0.01656103, 0.01391278, 0.01220081, 0.00744679])

# %% [markdown]
# 10개의 주성분이 약 97%를 설명

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9783866949468606

# %% [markdown]
# # 2. 15개

# %%
pca = PCA(n_components=15)
pca_componentes = pca.fit_transform(x)
pca_df = pd.DataFrame(data=pca_componentes)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.6571778 , 0.08785828, 0.0678797 , 0.06207163, 0.03383588,
#        0.01944202, 0.01656103, 0.01391278, 0.01220081, 0.00744679,
#        0.00671348, 0.00462555, 0.002851  , 0.00255846, 0.00179217])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9969273534463592

# %% [markdown]
# ## 20개

# %%
pca = PCA(n_components=20)
pca_componentes = pca.fit_transform(x)
pca_df = pd.DataFrame(data=pca_componentes)

# %%
pca.explained_variance_ratio_
# Out:
# array([6.57177796e-01, 8.78582848e-02, 6.78796960e-02, 6.20716267e-02,
#        3.38358789e-02, 1.94420150e-02, 1.65610304e-02, 1.39127754e-02,
#        1.22008069e-02, 7.44678530e-03, 6.71348237e-03, 4.62555135e-03,
#        2.85099570e-03, 2.55845913e-03, 1.79216995e-03, 9.89051869e-04,
#        7.54109113e-04, 4.53855733e-04, 3.57941570e-04, 2.65708155e-04])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9997480198868839

# %% [markdown]
# ## 25개

# %%
pca = PCA(n_components=25)
pca_componentes = pca.fit_transform(x)
pca_df = pd.DataFrame(data=pca_componentes)

# %%
pca.explained_variance_ratio_
# Out:
# array([6.57177796e-01, 8.78582848e-02, 6.78796960e-02, 6.20716267e-02,
#        3.38358789e-02, 1.94420150e-02, 1.65610304e-02, 1.39127754e-02,
#        1.22008069e-02, 7.44678530e-03, 6.71348237e-03, 4.62555135e-03,
#        2.85099570e-03, 2.55845913e-03, 1.79216995e-03, 9.89051869e-04,
#        7.54109113e-04, 4.53855733e-04, 3.57941570e-04, 2.65708155e-04,
#        2.48914975e-04, 3.06410686e-06, 8.81173299e-10, 5.97697662e-11,
#        1.82343215e-11])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999280853

# %% [markdown]
# ## 30개

# %%
pca = PCA(n_components=30)
pca_componentes = pca.fit_transform(x)
pca_df = pd.DataFrame(data=pca_componentes)

# %%
pca.explained_variance_ratio_
# Out:
# array([6.57177796e-01, 8.78582848e-02, 6.78796960e-02, 6.20716267e-02,
#        3.38358789e-02, 1.94420150e-02, 1.65610304e-02, 1.39127754e-02,
#        1.22008069e-02, 7.44678530e-03, 6.71348237e-03, 4.62555135e-03,
#        2.85099570e-03, 2.55845913e-03, 1.79216995e-03, 9.89051869e-04,
#        7.54109113e-04, 4.53855733e-04, 3.57941570e-04, 2.65708155e-04,
#        2.48914975e-04, 3.06410686e-06, 8.81173299e-10, 5.97697662e-11,
#        1.82343217e-11, 1.35821614e-11, 1.08016799e-11, 9.85752265e-12,
#        5.96619325e-12, 3.86938638e-12])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999721184

# %%
pca_df.head()
# Out:
#                0              1              2             3              4  \
# 0 -204850.823344   52770.958635  -51743.899750 -74094.166196   21946.601952
# 1  405653.596412 -815190.314707  -72709.247512 -90350.879616   -9774.509547
# 2 -206097.271223   56087.951247  -46743.977038 -74829.805697   22286.637301
# 3 -206110.538085   56100.026684  -52058.258223 -75115.582657   22935.645070
# 4 -198057.263585   36578.193179  549811.023693 -30953.314153  354887.688086
#
#               5             6             7             8             9  \
# 0 -23300.911088  23727.231274 -30247.425045 -23103.044105   7408.619239
# 1 -26803.618728 -97785.375838   9020.939667  29321.470960 -28361.754998
# 2 -25915.054240 -15540.751157 -25132.762138 -20575.290769   2169.965587
# 3 -25833.536815 -15445.108655 -24569.240560 -20111.362077   6878.747350
# 4 -42251.653508 -20923.867118 -77387.953170 -45056.072223 -90459.010687
#
#               10            11            12           13            14  \
# 0  -11950.476054 -3.860570e+02   6550.546304 -1809.734470  12354.730538
# 1  108151.816143  1.020552e+06 -27163.089526 -6517.407241 -15006.637866
# 2   -9793.305821 -7.871127e+02   6383.290653 -2101.591028  -3581.170802
# 3  -10112.348676 -6.988443e+02   6155.257574 -2069.970064  -3615.590460
# 4  -11004.365178  4.307013e+02   4776.089993 -2402.400549  -6734.460703
#
#             15           16            17           18          19  \
# 0 -1765.532818  -913.911833  -4753.598141  -311.099730  158.886880
# 1 -4371.368695  6926.029616  -4166.695129  2801.330307 -423.509777
# 2 -1762.940374  -798.431056   2178.362168  -123.843000  194.559192
# 3 -1741.241595  -705.336052  -4630.199739  -115.199268  166.597346
# 4  -483.816600   636.169325 -10300.849400  -744.716016 -356.222335
#
#             20         21          22         23        24        25  \
# 0  -252.534827 -33.843553  110.590546 -27.056662 -5.557922 -7.437375
# 1  -880.516877 -72.555617   17.599610   1.885057 -0.295097  4.397181
# 2  -210.008512 -90.216539  -12.022320  -0.424581  2.132270 -0.896373
# 3  -211.383901 -29.039198  -11.902679  -0.489280  2.116021 -0.737978
# 4 -1024.813899 -14.740073  -12.506657  -0.820884  1.473628 -0.811703
#
#          26        27         28        29
# 0  8.504220 -0.939240  13.948135 -2.563740
# 1  2.849485  5.051407  -2.122153 -2.285249
# 2  0.283040  1.422797   0.794404 -4.145374
# 3  0.236348  1.330976   0.209992  0.537108
# 4  0.283161  0.872398   0.755613 -6.354285

# %%
df = pd.concat([pca_df,y],axis=1)

# %%
df.head()
# Out:
#                0              1              2             3              4  \
# 0 -204850.823344   52770.958635  -51743.899750 -74094.166196   21946.601952
# 1  405653.596412 -815190.314707  -72709.247512 -90350.879616   -9774.509547
# 2 -206097.271223   56087.951247  -46743.977038 -74829.805697   22286.637301
# 3 -206110.538085   56100.026684  -52058.258223 -75115.582657   22935.645070
# 4 -198057.263585   36578.193179  549811.023693 -30953.314153  354887.688086
#
#               5             6             7             8             9  \
# 0 -23300.911088  23727.231274 -30247.425045 -23103.044105   7408.619239
# 1 -26803.618728 -97785.375838   9020.939667  29321.470960 -28361.754998
# 2 -25915.054240 -15540.751157 -25132.762138 -20575.290769   2169.965587
# 3 -25833.536815 -15445.108655 -24569.240560 -20111.362077   6878.747350
# 4 -42251.653508 -20923.867118 -77387.953170 -45056.072223 -90459.010687
#
#               10            11            12           13            14  \
# 0  -11950.476054 -3.860570e+02   6550.546304 -1809.734470  12354.730538
# 1  108151.816143  1.020552e+06 -27163.089526 -6517.407241 -15006.637866
# 2   -9793.305821 -7.871127e+02   6383.290653 -2101.591028  -3581.170802
# 3  -10112.348676 -6.988443e+02   6155.257574 -2069.970064  -3615.590460
# 4  -11004.365178  4.307013e+02   4776.089993 -2402.400549  -6734.460703
#
#             15           16            17           18          19  \
# 0 -1765.532818  -913.911833  -4753.598141  -311.099730  158.886880
# 1 -4371.368695  6926.029616  -4166.695129  2801.330307 -423.509777
# 2 -1762.940374  -798.431056   2178.362168  -123.843000  194.559192
# 3 -1741.241595  -705.336052  -4630.199739  -115.199268  166.597346
# 4  -483.816600   636.169325 -10300.849400  -744.716016 -356.222335
#
#             20         21          22         23        24        25  \
# 0  -252.534827 -33.843553  110.590546 -27.056662 -5.557922 -7.437375
# 1  -880.516877 -72.555617   17.599610   1.885057 -0.295097  4.397181
# 2  -210.008512 -90.216539  -12.022320  -0.424581  2.132270 -0.896373
# 3  -211.383901 -29.039198  -11.902679  -0.489280  2.116021 -0.737978
# 4 -1024.813899 -14.740073  -12.506657  -0.820884  1.473628 -0.811703
#
#          26        27         28        29  연체여부
# 0  8.504220 -0.939240  13.948135 -2.563740     0
# 1  2.849485  5.051407  -2.122153 -2.285249     0
# 2  0.283040  1.422797   0.794404 -4.145374     0
# 3  0.236348  1.330976   0.209992  0.537108     0
# 4  0.283161  0.872398   0.755613 -6.354285     0

# %% [markdown]
# 해당 데이터는 정규화(log) + RobustScaling + PCA한 결과임

# %%
df.to_csv('C:/Users/ksy/Desktop/개인/코로나19 팀프로젝트/시나리오2/data/PCA30.csv')
